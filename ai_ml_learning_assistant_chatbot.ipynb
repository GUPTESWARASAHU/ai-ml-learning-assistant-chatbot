# %%
import webbrowser

def open_search(query):
    # This function opens a Google search in a web browser.
    # It's called by various _info functions.
    search_url = f"https://www.google.com/search?q={query.replace(' ', '+')}"
    print(f"Searching Google for: {query} at {search_url}")
    # Uncomment the line below to actually open the browser tab
    # webbrowser.open(search_url)

def show_topics():
    print("\n===== Available Topics =====")
    print("1. Python")
    print("2. AI")
    print("3. Machine Learning")
    print("4. Data Science")
    print("5. Sports")
    print("6. Cyber Security")
    print("7. Data Structures")
    print("8. Prompt Engineering")


def show_resources(topic):

    resources = {
        "python": {
            "google": "https://www.google.com/search?q=Python+Programming",
            "youtube": "https://www.youtube.com/results?search_query=Python+Full+Course+Hindi",
            "gfg": "https://www.geeksforgeeks.org/python-programming-language/",
            "kaggle": "https://www.kaggle.com/learn/python",
            "fcc": "https://www.freecodecamp.org/learn"
        },

        "ai": {
            "google": "https://www.google.com/search?q=Artificial+Intelligence",
            "youtube": "https://www.youtube.com/results?search_query=Artificial+Intelligence+Hindi",
            "gfg": "https://www.geeksforgeeks.org/artificial-intelligence/",
            "kaggle": "https://www.kaggle.com/learn/intro-to-ai-ethics",
            "fcc": "https://www.freecodecamp.org/news/artificial-intelligence-guide/"
        },

        "machine learning": {
            "google": "https://www.google.com/search?q=Machine+Learning",
            "youtube": "https://www.youtube.com/results?search_query=Machine+Learning+Hindi",
            "gfg": "https://www.geeksforgeeks.org/machine-learning/",
            "kaggle": "https://www.kaggle.com/learn/intro-to-machine-learning",
            "fcc": "https://www.freecodecamp.org/news/machine-learning-course/"
        },

        "data science": {
            "google": "https://www.google.com/search?q=Data+Science",
            "youtube": "https://www.youtube.com/results?search_query=Data+Science+Hindi",
            "gfg": "https://www.geeksforgeeks.org/data-science-for-beginners/",
            "kaggle": "https://www.kaggle.com/learn",
            "fcc": "https://www.freecodecamp.org/news/data-science-learning-roadmap/"
        }
    }

    if topic in resources:

        print("\n===== Useful Resources =====")

        print("Google Search:")
        print(resources[topic]["google"])

        print("\nYouTube (Hindi):")
        print(resources[topic]["youtube"])

        print("\nGeeksforGeeks:")
        print(resources[topic]["gfg"])

        print("\nKaggle:")
        print(resources[topic]["kaggle"])

        print("\nfreeCodeCamp:")
        print(resources[topic]["fcc"])

        open_link = input("\nOpen Google Search? (yes/no): ").lower()

        if open_link == "yes":
            webbrowser.open(resources[topic]["google"])


# =========================
# PYTHON
# =========================

def python_info():
    print("\n========== PYTHON ==========")

    print("Python is a beginner-friendly programming language.")
    print("It is widely used in:")
    print("- Web Development")
    print("- Artificial Intelligence")
    print("- Machine Learning")
    print("- Data Science")
    print("- Automation")

    print("\nSkills to Learn:")
    print("- Variables")
    print("- Loops")
    print("- Functions")
    print("- OOP")
    print("- Libraries")

    print("\nUseful Resources:")
    print("Google Search:")
    print("https://www.google.com/search?q=Python+Programming")

    print("\nYouTube Hindi:")
    print("https://www.youtube.com/results?search_query=Python+Full+Course+Hindi")

    print("\nGeeksforGeeks:")
    print("https://www.geeksforgeeks.org/python-programming-language/")

    print("\nKaggle:")
    print("https://www.kaggle.com/learn/python")

    print("\nfreeCodeCamp:")
    print("https://www.freecodecamp.org/learn")

    print("\nMinor Projects:")
    print("1. Calculator")
    print("2. Hangman Game")
    print("3. To-Do List")
    print("4. Quiz Application")

    print("\nMajor Projects:")
    print("1. Face Recognition System")
    print("2. AI Chatbot")
    print("3. Inventory Management System")

    open_search("Python Programming")


# =========================
# AI
# =========================

def ai_info():
    print("\n========== ARTIFICIAL INTELLIGENCE ==========")

    print("AI enables machines to perform tasks that normally")
    print("require human intelligence.")

    print("\nDomains:")
    print("- Machine Learning")
    print("- Deep Learning")
    print("- NLP")
    print("- Computer Vision")

    print("\nResources:")
    print("Google:")
    print("https://www.google.com/search?q=Artificial+Intelligence")

    print("\nYouTube Hindi:")
    print("https://www.youtube.com/results?search_query=Artificial+Intelligence+Hindi")

    print("\nGeeksforGeeks:")
    print("https://www.geeksforgeeks.org/artificial-intelligence/")

    print("\nKaggle:")
    print("https://www.kaggle.com/learn")

    print("\nfreeCodeCamp:")
    print("https://www.freecodecamp.org/news/artificial-intelligence-guide/")

    print("\nMinor Projects:")
    print("1. Rule-Based Chatbot")
    print("2. Movie Recommendation System")
    print("3. Spam Detection")

    print("\nMajor Projects:")
    print("1. Virtual Assistant")
    print("2. Smart Attendance System")
    print("3. AI Interview System")

    open_search("Artificial Intelligence")


# =========================
# MACHINE LEARNING
# =========================

def ml_info():
    print("\n========== MACHINE LEARNING ==========")

    print("Machine Learning is a subset of AI.")
    print("It allows systems to learn from data.")

    print("\nLearn:")
    print("- Python")
    print("- Statistics")
    print("- NumPy")
    print("- Pandas")
    print("- Scikit-Learn")

    print("\nResources:")
    print("Google:")
    print("https://www.google.com/search?q=Machine+Learning")

    print("\nYouTube Hindi:")
    print("https://www.youtube.com/results?search_query=Machine+Learning+Hindi")

    print("\nGeeksforGeeks:")
    print("https://www.geeksforgeeks.org/machine-learning/")

    print("\nKaggle:")
    print("https://www.kaggle.com/learn/intro-to-machine-learning")

    print("\nfreeCodeCamp:")
    print("https://www.freecodecamp.org/news/machine-learning-course/")

    print("\nMinor Projects:")
    print("1. House Price Prediction")
    print("2. Student Score Prediction")
    print("3. Iris Flower Classification")

    print("\nMajor Projects:")
    print("1. Fraud Detection System")
    print("2. Medical Diagnosis System")
    print("3. AI Fitness Recommendation System")

    open_search("Machine Learning")


# =========================
# DATA SCIENCE
# =========================

def data_science_info():
    print("\n========== DATA SCIENCE ==========")

    print("Data Science focuses on extracting insights from data.")

    print("\nLearn:")
    print("- Python")
    print("- SQL")
    print("- Power BI")
    print("- Statistics")
    print("- Data Visualization")

    print("\nResources:")
    print("Google:")
    print("https://www.google.com/search?q=Data+Science")

    print("\nYouTube Hindi:")
    print("https://www.youtube.com/results?search_query=Data+Science+Hindi")

    print("\nGeeksforGeeks:")
    print("https://www.geeksforgeeks.org/data-science-for-beginners/")

    print("\nKaggle:")
    print("https://www.kaggle.com/learn")

    print("\nfreeCodeCamp:")
    print("https://www.freecodecamp.org/news/data-science-learning-roadmap/")

    print("\nMinor Projects:")
    print("1. IPL Data Analysis")
    print("2. Sales Dashboard")
    print("3. COVID Data Analysis")

    print("\nMajor Projects:")
    print("1. Customer Churn Prediction")
    print("2. Business Intelligence Dashboard")
    print("3. Stock Market Analysis")

    open_search("Data Science")


# =========================
# CYBER SECURITY
# =========================

def cyber_info():
    print("\n========== CYBER SECURITY ==========")

    print("Cyber Security protects systems, networks,")
    print("and data from cyber threats.")

    print("\nLearn:")
    print("- Networking")
    print("- Linux")
    print("- Ethical Hacking")
    print("- Cryptography")
    print("- Penetration Testing")

    print("\nResources:")
    print("Google:")
    print("https://www.google.com/search?q=Cyber+Security")

    print("\nYouTube Hindi:")
    print("https://www.youtube.com/results?search_query=Cyber+Security+Hindi")

    print("\nGeeksforGeeks:")
    print("https://www.geeksforgeeks.org/cyber-security-tutorial/")

    print("\nMinor Projects:")
    print("1. Password Strength Checker")
    print("2. Port Scanner")
    print("3. Login Security Checker")

    print("\nMajor Projects:")
    print("1. Intrusion Detection System")
    print("2. Malware Detection Tool")
    print("3. Secure File Sharing System")

    open_search("Cyber Security")


# =========================
# DSA
# =========================

def dsa_info():
    print("\n========== DATA STRUCTURES ==========")

    print("Data Structures organize and store data efficiently.")

    print("\nTopics:")
    print("- Arrays")
    print("- Linked Lists")
    print("- Stacks")
    print("- Queues")
    print("- Trees")
    print("- Graphs")
    print("- Heaps")

    print("\nResources:")
    print("Google:")
    print("https://www.google.com/search?q=Data+Structures")

    print("\nYouTube Hindi:")
    print("https://www.youtube.com/results?search_query=Data+Structures+Hindi")

    print("\nGeeksforGeeks:")
    print("https://www.geeksforgeeks.org/data-structures/")

    print("\nMinor Projects:")
    print("1. Student Record System")
    print("2. Library Management")
    print("3. Expression Evaluator")

    print("\nMajor Projects:")
    print("1. AI Game Matchmaking System")
    print("2. Social Network Graph Analyzer")
    print("3. Route Optimization System")

    open_search("Data Structures")


# =========================
# PROMPT ENGINEERING
# =========================

def prompt_info():
    print("\n========== PROMPT ENGINEERING ==========")

    print("Prompt Engineering is the skill of creating")
    print("effective prompts for AI systems.")

    print("\nLearn:")
    print("- Prompt Design")
    print("- Few-Shot Prompting")
    print("- Chain of Thought")
    print("- RAG")
    print("- AI Agents")

    print("\nResources:")
    print("Google:")
    print("https://www.google.com/search?q=Prompt+Engineering")

    print("\nYouTube Hindi:")
    print("https://www.youtube.com/results?search_query=Prompt+Engineering+Hindi")

    print("\nfreeCodeCamp:")
    print("https://www.freecodecamp.org/news/prompt-engineering-guide/")

    print("\nMinor Projects:")
    print("1. Resume Generator")
    print("2. AI Study Planner")
    print("3. Email Writer")

    print("\nMajor Projects:")
    print("1. AI Research Assistant")
    print("2. Career Guidance Chatbot")
    print("3. Multi-Agent AI System")

    open_search("Prompt Engineering")


# =========================
# SPORTS
# =========================

def sports_info():
    print("\n========== SPORTS ==========")

    print("Sports improve fitness, teamwork, discipline,")
    print("leadership, and mental strength.")

    print("\nPopular Sports:")
    print("- Cricket")
    print("- Football")
    print("- Basketball")
    print("- Volleyball")
    print("- Badminton")

    open_search("Sports")


# =========================
# CHATBOT FUNCTION
# =========================

def chatbot():
    print("Bot: Hello! How can I help you today?")
    while True:
        user = input("You: ").lower()

        if user == "topics":
            show_topics()
        elif user == "python":
            python_info()
            show_resources("python")
        elif user == "ai":
            ai_info()
            show_resources("ai")
        elif user == "machine learning":
            ml_info()
            show_resources("machine learning")
        elif user == "data science":
            data_science_info()
            show_resources("data science")
        elif user == "cyber security":
            cyber_info()
        elif user == "data structures":
            dsa_info()
        elif user == "prompt engineering":
            prompt_info()
        elif user == "sports":
            sports_info()
            # This line was present in the original snippet, keeping it for consistency.
            print("Bot: Sports improve fitness, teamwork, and discipline.")
        elif user == "bye":
            print("Bot: Goodbye! Keep Learning 🚀")
            break
        else:
            print("Bot: Sorry, I don't understand that.")
            print("Type 'topics' to see available topics.")


chatbot()
# Out:
# Bot: Hello! How can I help you today?
# You: topics
#
# ===== Available Topics =====
# 1. Python
# 2. AI
# 3. Machine Learning
# 4. Data Science
# 5. Sports
# 6. Cyber Security
# 7. Data Structures
# 8. Prompt Engineering
# You: cyber security
#
# ========== CYBER SECURITY ==========
# Cyber Security protects systems, networks,
# and data from cyber threats.
#
# Learn:
# - Networking
# - Linux
# - Ethical Hacking
# - Cryptography
# - Penetration Testing
#
# Resources:
# Google:
# https://www.google.com/search?q=Cyber+Security
#
# YouTube Hindi:
# https://www.youtube.com/results?search_query=Cyber+Security+Hindi
#
# GeeksforGeeks:
# https://www.geeksforgeeks.org/cyber-security-tutorial/
#
# Minor Projects:
# 1. Password Strength Checker
# 2. Port Scanner
# 3. Login Security Checker
#
# Major Projects:
# 1. Intrusion Detection System
# 2. Malware Detection Tool
# 3. Secure File Sharing System
# Searching Google for: Cyber Security at https://www.google.com/search?q=Cyber+Security
# ...
